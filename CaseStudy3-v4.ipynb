# %% [markdown]
# <a href="https://colab.research.google.com/github/sushantagarwal29/ragpoc/blob/main/CaseStudy3-v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install azure.ai.documentintelligence
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.core.credentials import AzureKeyCredential
import base64
import pandas as pd
import os
# Out:
# Collecting azure.ai.documentintelligence
#   Downloading azure_ai_documentintelligence-1.0.0-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 1.8 MB/s eta 0:00:00
# Collecting isodate>=0.6.1 (from azure.ai.documentintelligence)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure.ai.documentintelligence)
#   Downloading azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from azure.ai.documentintelligence) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure.ai.documentintelligence) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure.ai.documentintelligence) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure.ai.documentintelligence) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure.ai.documentintelligence) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure.ai.documentintelligence) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure.ai.documentintelligence) (2025.1.31)
# Downloading azure_ai_documentintelligence-1.0.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 4.6 MB/s eta 0:00:00
# Downloading azure_core-1.32.0-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 8.9 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-core, azure.ai.documentintelligence
# Successfully installed azure-core-1.32.0 azure.ai.documentintelligence-1.0.0 isodate-0.7.2

# %%
# Replace with your endpoint and API key
endpoint = "https://doci-daai-poc.cognitiveservices.azure.com/"
api_key = "9EIMncoOBRAdVNJUHjZ8OnWcec6wZrBiGTjTJjd26tK6kKVOoE72JQQJ99AKACHrzpqXJ3w3AAALACOGV2mb"
credential = AzureKeyCredential(api_key)

# %%
# Authenticate the client
client = DocumentIntelligenceClient(endpoint=endpoint, credential=credential)

# %%
filepath = "/content/Daily_Sports_Highlights_01092024_With_Subsections.pdf"

# %%
# Process the PDF
with open(filepath, "rb") as f:
  pdf_content = f.read()
  base64_pdf = base64.b64encode(pdf_content).decode("utf-8")

poller = client.begin_analyze_document('prebuilt-contract', body={"base64Source": base64_pdf})
result = poller.result()

# %%
print(result)
# Out:
# {'apiVersion': '2024-11-30', 'modelId': 'prebuilt-contract', 'stringIndexType': 'textElements', 'content': "01.09.2024 Daily Sports Highlights\nFootball\nLionel Messi Leads Inter Miami to Victory in MLS Cup Final\nSource: ESPN - September 1, 2024\nLionel Messi's incredible performance secured Inter Miami's first MLS Cup victory, defeating LAFC 3-2 in a thrilling final. Messi scored twice, with his second goal in the 85th minute sealing the win. This victory cements Messi's status as one of the greatest footballers in the history of the sport.\nLink: https://www.espn.com/soccer/story/lionel-messi-leads-inter-miami-victory-mls-cup-final\nCristiano Ronaldo Scores 800th Career Goal\nSource: Sky Sports - September 1, 2024\nCristiano Ronaldo has reached another milestone in his illustrious career by scoring his 800th career goal. The Portuguese star continues to break records and is widely regarded as one of the greatest footballers of all time.\nLink: https://www.skysports.com/football/ronaldo-scores-800th-goal\nTennis\nSerena Williams Announces Retirement After US Open\nSource: BBC Sports - September 1, 2024\nTennis legend Serena Williams has announced that she will retire from professional tennis after the US Open. Williams, who has won 23 Grand Slam singles titles, is considered one of the greatest tennis players of all time.\nLink: https://www.bbc.com/sport/tennis/serena-williams-retires\nRafael Nadal Announces Full Recovery, Set to Compete in Australian Open\nSource: ESPN - September 1, 2024\nRafael Nadal has announced that he has fully recovered from his recent injury and is set to compete in the upcoming Australian Open. Nadal, who has won 22 Grand Slam titles, is eager to add another title to his collection.\nLink: https://www.espn.com/tennis/nadal-australian-open-return\nNaomi Osaka Returns to Tennis with a Victory at the Tokyo Open\nSource: The Guardian - September 1, 2024\nNaomi Osaka made a triumphant return to tennis by winning the Tokyo Open. This victory marks her first title since taking a break from the sport to focus on her mental health.\nLink: https://www.theguardian.com/sport/naomi-osaka-wins-tokyo-open\nBasketball\nLeBron James Breaks All-Time NBA Scoring Record\nSource: NBA.com - September 1, 2024\nLeBron James has officially become the NBA's all-time leading scorer, surpassing Kareem Abdul-Jabbar's record. In a game against the Golden State Warriors, LeBron's historic moment came with a fadeaway jumper in the third quarter. Link: https://www.nba.com/news/lebron-james-breaks-all-time-nba-scoring-record\nGymnastics\nSimone Biles Wins Record 8th All-Around World Title\nSource: CNN - September 1, 2024\nSimone Biles has won her 8th all-around world title at the World Gymnastics Championships, further cementing her legacy as the greatest gymnast of all time. Biles continues to push the boundaries of the sport with her extraordinary skills.\nLink: https://www.cnn.com/simone-biles-wins-8th-world-title\nFormula 1\nMax Verstappen Wins Italian Grand Prix\nSource: Formula 1 - September 1, 2024\nMax Verstappen dominated the Italian Grand Prix, securing his victory at Monza. The Red Bull driver showed exceptional speed and strategy, further solidifying his lead in the World Championship standings.\nLink: https://www.formula1.com/verstappen-wins-italian-grand-prix\nGolf\nTiger Woods Inducted into World Golf Hall of Fame\nSource: Golf Digest - September 1, 2024\nTiger Woods has been officially inducted into the World Golf Hall of Fame. Woods, one of the most successful golfers in history, has had a profound impact on the sport and continues to inspire future generations.\nLink: https://www.golfdigest.com/story/tiger-woods-inducted-hall-of-fame\nNFL\nTom Brady Signs Multi-Year Deal with Fox Sports\nSource: Fox Sports - September 1, 2024\nNFL legend Tom Brady has signed a multi-year deal with Fox Sports to become the lead analyst for its NFL coverage. This marks a new chapter in Brady's illustrious career following his retire ...
